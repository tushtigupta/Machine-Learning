# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Student Peformance.csv")
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 468.9+ KB

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
## UNIVARIENT ANALAYSIS

# %%
sns.displot(df['Hours Studied'])

# %%
# OBSERVATION
# Here,x axis is taken as Count and y axis is taken as Hours studied. 
#The maximum hour is studied is approximately equally to 1100 hours, as describe by a bar graph.

# %%
sns.kdeplot(df['Previous Scores'])
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Density'>

# %%
# OBSERVATION
# Here,x axis is taken as Density and y axis is taken as Previous Scores.
# According to the line plot, there is a significant increase in the scores relative to the density.

# %%
# BIVARIENT ANALAYSIS
sns.barplot(x=df['Sample Question Papers Practiced'],y=df['Performance Index'])
# Out:
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Performance Index'>

# %%
# OBSERVATION
# Bivarient Analysis is being performed to indentify the specific details,mentioning the required x and y columns
# Here,x axis is taken as Performace Index and y axis is taken as Sample Question Practiced.
# According to the above bar plot , 9 sample question paper is being practiced on an average of 55 days

# %%
# MULTIVARIENT ANALYSIS
sns.pairplot(df)
